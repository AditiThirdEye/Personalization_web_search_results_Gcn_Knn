# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.getcwd()
os.chdir("/content/drive/MyDrive/Mini_PersonalizationOfInformation")

# %%
# ! pip install -r requirements.txt

# %%
# !pip install spektral.layers

# %%
# ! pip install stellargraph

# %%
import numpy as np
import os
import networkx as nx
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.metrics import classification_report

from spektral.layers import GraphConv

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dropout, Dense
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
from tensorflow.keras.regularizers import l2

from collections import Counter
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

import stellargraph as sg

# %%
all_data = []
all_edges = []

with open('cora/cora.content','r') as f:
  all_data.extend(f.read().splitlines())
with open('cora/cora.cites','r') as f:
  all_edges.extend(f.read().splitlines())          
#Shuffle the data because the raw data is ordered based on the label
random_state = 77
all_data = shuffle(all_data,random_state=random_state)

# %%
labels = []
nodes = []
X = []

for i,data in enumerate(all_data):
    elements = data.split('\t')
    labels.append(elements[-1])
    X.append(elements[1:-1])
    nodes.append(elements[0])

X = np.array(X,dtype=int)
N = X.shape[0] #the number of nodes
F = X.shape[1] #the size of node features
print('X shape: ', X.shape)


#parse the edge
edge_list=[]
for edge in all_edges:
    e = edge.split('\t')
    edge_list.append((e[0],e[1]))

print('\nNumber of nodes (N): ', N)
print('\nNumber of features (F) of each node: ', F)
print('\nCategories: ', set(labels))

num_classes = len(set(labels))
print('\nNumber of classes: ', num_classes)
# Out:
# X shape:  (2708, 1433)
#
# Number of nodes (N):  2708
#
# Number of features (F) of each node:  1433
#
# Categories:  {'Case_Based', 'Genetic_Algorithms', 'Rule_Learning', 'Neural_Networks', 'Theory', 'Probabilistic_Methods', 'Reinforcement_Learning'}
#
# Number of classes:  7

# %%
def limit_data(labels,limit=20,val_num=500,test_num=1000):
    '''
    Get the index of train, validation, and test data
    '''
    label_counter = dict((l, 0) for l in labels)
    train_idx = []

    for i in range(len(labels)):
        label = labels[i]
        if label_counter[label]<limit:
            #add the example to the training data
            train_idx.append(i)
            label_counter[label]+=1
        
        #exit the loop once we found 20 examples for each class
        if all(count == limit for count in label_counter.values()):
            break
    
    #get the indices that do not go to traning data
    rest_idx = [x for x in range(len(labels)) if x not in train_idx]
    #get the first val_num
    val_idx = rest_idx[:val_num]
    test_idx = rest_idx[val_num:(val_num+test_num)]
    return train_idx, val_idx,test_idx


train_idx,val_idx,test_idx = limit_data(labels)
print("Length of Train : ", len(train_idx))
print("Lehgth of Validation : ", len(val_idx))
print("Length of Test : ", len(test_idx))
# Out:
# Length of Train :  140
# Lehgth of Validation :  500
# Length of Test :  1000

# %%
#set the mask
train_mask = np.zeros((N,),dtype=bool)
train_mask[train_idx] = True

val_mask = np.zeros((N,),dtype=bool)
val_mask[val_idx] = True

test_mask = np.zeros((N,),dtype=bool)
test_mask[test_idx] = True

# %%
print("All Data Distribution: \n{}".format(Counter(labels)))
# Out:
# All Data Distribution:
# Counter({'Neural_Networks': 818, 'Probabilistic_Methods': 426, 'Genetic_Algorithms': 418, 'Theory': 351, 'Case_Based': 298, 'Reinforcement_Learning': 217, 'Rule_Learning': 180})

# %%
print("Training Data Distribution: \n{}".format(Counter([labels[i] for i in train_idx])))
# Out:
# Training Data Distribution:
# Counter({'Reinforcement_Learning': 20, 'Probabilistic_Methods': 20, 'Neural_Networks': 20, 'Case_Based': 20, 'Theory': 20, 'Genetic_Algorithms': 20, 'Rule_Learning': 20})

# %%
print("Validation Data Distribution: \n{}".format(Counter([labels[i] for i in val_idx])))
# Out:
# Validation Data Distribution:
# Counter({'Neural_Networks': 172, 'Genetic_Algorithms': 78, 'Probabilistic_Methods': 72, 'Theory': 63, 'Case_Based': 58, 'Reinforcement_Learning': 35, 'Rule_Learning': 22})

# %%
def encode_label(labels):
    label_encoder = LabelEncoder()
    labels = label_encoder.fit_transform(labels)
    labels = to_categorical(labels)
    return labels, label_encoder.classes_

labels_encoded, classes = encode_label(labels)

# %%
G = nx.Graph()
G.add_nodes_from(nodes)
G.add_edges_from(edge_list)

#obtain the adjacency matrix (A)
A = nx.adjacency_matrix(G)
print('Graph info: ', nx.info(G))
# Out:
# Graph info:  Name:
# Type: Graph
# Number of nodes: 2708
# Number of edges: 5278
# Average degree:   3.8981

# %%
channels = 16           # Number of channels in the first layer
dropout = 0.5           # Dropout rate for the features
l2_reg = 5e-4           # L2 regularization rate
learning_rate = 1e-2    # Learning rate
epochs = 200            # Number of training epochs
es_patience = 10        # Patience for early stopping

# Preprocessing operations
A = GraphConv.preprocess(A).astype('f4')

# Model definition
X_in = Input(shape=(F, ))
fltr_in = Input((N, ), sparse=True)

dropout_1 = Dropout(dropout)(X_in)
graph_conv_1 = GraphConv(channels,
                         activation='relu',
                         kernel_regularizer=l2(l2_reg),
                         use_bias=False)([dropout_1, fltr_in])

dropout_2 = Dropout(dropout)(graph_conv_1)
graph_conv_2 = GraphConv(num_classes,
                         activation='softmax',
                         use_bias=False)([dropout_2, fltr_in])

# Build model
model = Model(inputs=[X_in, fltr_in], outputs=graph_conv_2)
optimizer = Adam(lr=learning_rate)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              weighted_metrics=['acc'])
model.summary()

tbCallBack_GCN = tf.keras.callbacks.TensorBoard(
    log_dir='./Tensorboard_GCN_cora',
)
callback_GCN = [tbCallBack_GCN]
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1433)]       0
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1433)         0           input_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 2708)]       0
# __________________________________________________________________________________________________
# graph_conv (GraphConv)          (None, 16)           22928       dropout[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16)           0           graph_conv[0][0]
# __________________________________________________________________________________________________
# graph_conv_1 (GraphConv)        (None, 7)            112         dropout_1[0][0]
#                                                                  input_2[0][0]
# ==================================================================================================
# Total params: 23,040
# Trainable params: 23,040
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train model
validation_data = ([X, A], labels_encoded, val_mask)
history = model.fit([X, A],
          labels_encoded,
          sample_weight=train_mask,
          epochs=epochs,
          batch_size=N,
          validation_data=validation_data,
          shuffle=False,
          callbacks=[
              EarlyStopping(patience=10,  restore_best_weights=True),
              tbCallBack_GCN
          ])
# Out:
# Epoch 1/200
# 1/1 [==============================] - 1s 844ms/step - loss: 0.1168 - acc: 0.1071 - val_loss: 0.3628 - val_acc: 0.3900
# Epoch 2/200
# 1/1 [==============================] - ETA: 0s - loss: 0.1092 - acc: 0.3000WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.645799). Check your callbacks.
# 1/1 [==============================] - 0s 314ms/step - loss: 0.1092 - acc: 0.3000 - val_loss: 0.3527 - val_acc: 0.4780
# Epoch 3/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1031 - acc: 0.4643 - val_loss: 0.3400 - val_acc: 0.5460
# Epoch 4/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0980 - acc: 0.4429 - val_loss: 0.3259 - val_acc: 0.5860
# Epoch 5/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0928 - acc: 0.5571 - val_loss: 0.3119 - val_acc: 0.6080
# Epoch 6/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0885 - acc: 0.5643 - val_loss: 0.2992 - val_acc: 0.6360
# Epoch 7/200
# 1/1 [==============================] - 0s 296ms/step - loss: 0.0843 - acc: 0.6357 - val_loss: 0.2877 - val_acc: 0.6420
# Epoch 8/200
# 1/1 [==============================] - 0s 266ms/step - loss: 0.0823 - acc: 0.6357 - val_loss: 0.2782 - val_acc: 0.6780
# Epoch 9/200
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0785 - acc: 0.6643 - val_loss: 0.2700 - val_acc: 0.7180
# Epoch 10/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0762 - acc: 0.7286 - val_loss: 0.2631 - val_acc: 0.7400
# Epoch 11/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0736 - acc: 0.7786 - val_loss: 0.2573 - val_acc: 0.7580
# Epoch 12/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0736 - acc: 0.8143 - val_loss: 0.2521 - val_acc: 0.7700
# Epoch 13/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0721 - acc: 0.8143 - val_loss: 0.2470 - val_acc: 0.7800
# Epoch 14/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0677 - acc: 0.8857 - val_loss: 0.2414 - val_acc: 0.7880
# Epoch 15/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0688 - acc: 0.8286 - val_loss: 0.2360 - val_acc: 0.7880
# Epoch 16/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0663 - acc: 0.9000 - val_loss: 0.2305 - val_acc: 0.8000
# Epoch 17/200
# 1/1 [==============================] - 0s 297ms/step - loss: 0.0644 - acc: 0.8857 - val_loss: 0.2252 - val_acc: 0.8000
# Epoch 18/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0662 - acc: 0.8571 - val_loss: 0.2201 - val_acc: 0.8020
# Epoch 19/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0626 - acc: 0.9143 - val_loss: 0.2158 - val_acc: 0.8040
# Epoch 20/200
# 1/1 [==============================] - 0s 315ms/step - loss: 0.0622 - acc: 0.8857 - val_loss: 0.2120 - val_acc: 0.7980
# Epoch 21/200
# 1/1 [==============================] - 0s 312ms/step - loss: 0.0587 - acc: 0.8929 - val_loss: 0.2089 - val_acc: 0.8020
# Epoch 22/200
# 1/1 [==============================] - 0s 305ms/step - loss: 0.0578 - acc: 0.8857 - val_loss: 0.2066 - val_acc: 0.8000
# Epoch 23/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0561 - acc: 0.8857 - val_loss: 0.2048 - val_acc: 0.8000
# Epoch 24/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0566 - acc: 0.9143 - val_loss: 0.2029 - val_acc: 0.7920
# Epoch 25/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0552 - acc: 0.9143 - val_loss: 0.2008 - val_acc: 0.7880
# Epoch 26/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0572 - acc: 0.9000 - val_loss: 0.1984 - val_acc: 0.7880
# Epoch 27/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0552 - acc: 0.9214 - val_loss: 0.1953 - val_acc: 0.7900
# Epoch 28/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0510 - acc: 0.9214 - val_loss: 0.1925 - val_acc: 0.7940
# Epoch 29/200
# 1/1 [==============================] - 0s 318ms/step - loss: 0.0562 - acc: 0.8929 - val_loss: 0.1901 - val_acc: 0.7940
# Epoch 30/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0513 - acc: 0.9143 - val_loss: 0.1879 - val_acc: 0.7940
# Epoch 31/200
# 1/1 [==============================] - 0s 308ms/step - loss: 0.0504 - acc: 0.9214 - val_loss: 0.1860 - val_acc: 0.7940
# Epoch 32/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0488 - acc: 0.9500 - val_loss: 0.1843 - val_acc: 0.7940
# Epoch 33/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0494 - acc: 0.9143 - val_loss: 0.1822 - val_acc: 0.7980
# Epoch 34/200
# 1/1 [==============================] - 0s 298ms/step - loss: 0.0477 - acc: 0.9571 - val_loss: 0.1806 - val_acc: 0.7980
# Epoch 35/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0478 - acc: 0.9357 - val_loss: 0.1793 - val_acc: 0.7960
# Epoch 36/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0462 - acc: 0.9357 - val_loss: 0.1784 - val_acc: 0.7960
# Epoch 37/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0465 - acc: 0.9429 - val_loss: 0.1775 - val_acc: 0.7960
# Epoch 38/200
# 1/1 [==============================] - 0s 283ms/step - loss: 0.0461 - acc: 0.9357 - val_loss: 0.1774 - val_acc: 0.7900
# Epoch 39/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0446 - acc: 0.9143 - val_loss: 0.1769 - val_acc: 0.7860
# Epoch 40/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0431 - acc: 0.9500 - val_loss: 0.1759 - val_acc: 0.7860
# Epoch 41/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0444 - acc: 0.9286 - val_loss: 0.1743 - val_acc: 0.7880
# Epoch 42/200
# 1/1 [==============================] - 0s 282ms/step - loss: 0.0434 - acc: 0.9357 - val_loss: 0.1731 - val_acc: 0.7880
# Epoch 43/200
# 1/1 [==============================] - 0s 298ms/step - loss: 0.0426 - acc: 0.9286 - val_loss: 0.1715 - val_acc: 0.7880
# Epoch 44/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0434 - acc: 0.9571 - val_loss: 0.1703 - val_acc: 0.7860
# Epoch 45/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0433 - acc: 0.9214 - val_loss: 0.1692 - val_acc: 0.7880
# Epoch 46/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0418 - acc: 0.9643 - val_loss: 0.1680 - val_acc: 0.7880
# Epoch 47/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0430 - acc: 0.9286 - val_loss: 0.1666 - val_acc: 0.7900
# Epoch 48/200
# 1/1 [==============================] - 0s 299ms/step - loss: 0.0414 - acc: 0.9500 - val_loss: 0.1645 - val_acc: 0.7900
# Epoch 49/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0424 - acc: 0.9500 - val_loss: 0.1632 - val_acc: 0.7900
# Epoch 50/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0397 - acc: 0.9571 - val_loss: 0.1624 - val_acc: 0.7900
# Epoch 51/200
# 1/1 [==============================] - 0s 291ms/step - loss: 0.0399 - acc: 0.9500 - val_loss: 0.1616 - val_acc: 0.7880
# Epoch 52/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0377 - acc: 0.9571 - val_loss: 0.1606 - val_acc: 0.7900
# Epoch 53/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0379 - acc: 0.9571 - val_loss: 0.1597 - val_acc: 0.7960
# Epoch 54/200
# 1/1 [==============================] - 0s 288ms/step - loss: 0.0377 - acc: 0.9571 - val_loss: 0.1586 - val_acc: 0.7960
# Epoch 55/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0369 - acc: 0.9500 - val_loss: 0.1582 - val_acc: 0.7980
# Epoch 56/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0411 - acc: 0.9429 - val_loss: 0.1581 - val_acc: 0.7980
# Epoch 57/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0384 - acc: 0.9429 - val_loss: 0.1592 - val_acc: 0.8000
# Epoch 58/200
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0382 - acc: 0.9643 - val_loss: 0.1609 - val_acc: 0.7920
# Epoch 59/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0370 - acc: 0.9643 - val_loss: 0.1624 - val_acc: 0.7840
# Epoch 60/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0400 - acc: 0.9286 - val_loss: 0.1629 - val_acc: 0.7840
# Epoch 61/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0380 - acc: 0.9286 - val_loss: 0.1623 - val_acc: 0.7840
# Epoch 62/200
# 1/1 [==============================] - 0s 267ms/step - loss: 0.0364 - acc: 0.9429 - val_loss: 0.1602 - val_acc: 0.7820
# Epoch 63/200
# 1/1 [==============================] - 0s 285ms/step - loss: 0.0377 - acc: 0.9286 - val_loss: 0.1574 - val_acc: 0.7880
# Epoch 64/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0356 - acc: 0.9929 - val_loss: 0.1549 - val_acc: 0.7860
# Epoch 65/200
# 1/1 [==============================] - 0s 306ms/step - loss: 0.0364 - acc: 0.9429 - val_loss: 0.1542 - val_acc: 0.7900
# Epoch 66/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0390 - acc: 0.9214 - val_loss: 0.1544 - val_acc: 0.7880
# Epoch 67/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0360 - acc: 0.9571 - val_loss: 0.1551 - val_acc: 0.7900
# Epoch 68/200
# 1/1 [==============================] - 0s 279ms/step - loss: 0.0355 - acc: 0.9500 - val_loss: 0.1562 - val_acc: 0.7960
# Epoch 69/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0333 - acc: 0.9857 - val_loss: 0.1574 - val_acc: 0.7940
# Epoch 70/200
# 1/1 [==============================] - 0s 289ms/step - loss: 0.0351 - acc: 0.9714 - val_loss: 0.1587 - val_acc: 0.7920
# Epoch 71/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0335 - acc: 0.9643 - val_loss: 0.1586 - val_acc: 0.7880
# Epoch 72/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0352 - acc: 0.9643 - val_loss: 0.1583 - val_acc: 0.7820
# Epoch 73/200
# 1/1 [==============================] - 0s 295ms/step - loss: 0.0335 - acc: 0.9429 - val_loss: 0.1575 - val_acc: 0.7700
# Epoch 74/200
# 1/1 [==============================] - 0s 281ms/step - loss: 0.0346 - acc: 0.9643 - val_loss: 0.1558 - val_acc: 0.7720
# Epoch 75/200
# 1/1 [==============================] - 0s 292ms/step - loss: 0.0345 - acc: 0.9500 - val_loss: 0.1525 - val_acc: 0.7800
# Epoch 76/200
# 1/1 [==============================] - 0s 276ms/step - loss: 0.0350 - acc: 0.9500 - val_loss: 0.1494 - val_acc: 0.7880
# Epoch 77/200
# 1/1 [==============================] - 0s 286ms/step - loss: 0.0344 - acc: 0.9643 - val_loss: 0.1477 - val_acc: 0.7880
# Epoch 78/200
# 1/1 [==============================] - 0s 273ms/step - loss: 0.0315 - acc: 0.9643 - val_loss: 0.1476 - val_acc: 0.7820
# Epoch 79/200
# 1/1 [==============================] - 0s 290ms/step - loss: 0.0316 - acc: 0.9643 - val_loss: 0.1476 - val_acc: 0.7940
# Epoch 80/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0337 - acc: 0.9357 - val_loss: 0.1491 - val_acc: 0.7940
# Epoch 81/200
# 1/1 [==============================] - 0s 270ms/step - loss: 0.0326 - acc: 0.9786 - val_loss: 0.1502 - val_acc: 0.8000
# Epoch 82/200
# 1/1 [==============================] - 0s 275ms/step - loss: 0.0328 - acc: 0.9429 - val_loss: 0.1504 - val_acc: 0.8000
# Epoch 83/200
# 1/1 [==============================] - 0s 284ms/step - loss: 0.0313 - acc: 0.9857 - val_loss: 0.1504 - val_acc: 0.7960
# Epoch 84/200
# 1/1 [==============================] - 0s 278ms/step - loss: 0.0317 - acc: 0.9643 - val_loss: 0.1504 - val_acc: 0.7880
# Epoch 85/200
# 1/1 [==============================] - 0s 294ms/step - loss: 0.0330 - acc: 0.9714 - val_loss: 0.1504 - val_acc: 0.7780
# Epoch 86/200
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0310 - acc: 0.9643 - val_loss: 0.1507 - val_acc: 0.7740
# Epoch 87/200
# 1/1 [==============================] - 0s 293ms/step - loss: 0.0301 - acc: 0.9786 - val_loss: 0.1507 - val_acc: 0.7740
# Epoch 88/200
# 1/1 [==============================] - 0s 280ms/step - loss: 0.0348 - acc: 0.9500 - val_loss: 0.1507 - val_acc: 0.7760
# Epoch 89/200
# 1/1 [==============================] - 0s 277ms/step - loss: 0.0310 - acc: 0.9643 - val_loss: 0.1507 - val_acc: 0.7800

# %%
sg.utils.plot_history(history)

# %%
# Evaluate model
X_te = X[test_mask]
A_te = A[test_mask,:][:,test_mask]
y_te = labels_encoded[test_mask]

y_pred = model.predict([X_te, A_te], batch_size=N)
report = classification_report(np.argmax(y_te,axis=1), np.argmax(y_pred,axis=1), target_names=classes)
print('GCN Classification Report: \n {}'.format(report))
# Out:
# GCN Classification Report:
#                          precision    recall  f1-score   support
#
#             Case_Based       0.75      0.77      0.76       114
#     Genetic_Algorithms       0.86      0.88      0.87       156
#        Neural_Networks       0.79      0.72      0.75       290
#  Probabilistic_Methods       0.77      0.74      0.76       172
# Reinforcement_Learning       0.75      0.79      0.77        85
#          Rule_Learning       0.56      0.80      0.66        60
#                 Theory       0.67      0.66      0.66       123
#
#               accuracy                           0.76      1000
#              macro avg       0.74      0.77      0.75      1000
#           weighted avg       0.76      0.76      0.76      1000

# %%
layer_outputs = [layer.output for layer in model.layers]
activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict([X,A],batch_size=N)

#Get t-SNE Representation
#get the hidden layer representation after the first GCN layer
x_tsne = TSNE(n_components=2).fit_transform(activations[3])

# %%
def plot_tSNE(labels_encoded,x_tsne):
    color_map = np.argmax(labels_encoded, axis=1)
    plt.figure(figsize=(10,10))
    for cl in range(num_classes):
        indices = np.where(color_map==cl)
        indices = indices[0]
        plt.scatter(x_tsne[indices,0], x_tsne[indices, 1], label=cl)
    plt.legend()
    plt.show()
    
plot_tSNE(labels_encoded,x_tsne)
